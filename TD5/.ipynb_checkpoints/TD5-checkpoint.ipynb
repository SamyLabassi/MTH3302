# %% [markdown]
# # MTH3302 : Méthodes probabilistes et statistiques pour l'I.A.
#
# Jonathan Jalbert<br/>
# Professeur agrégé au Département de mathématiques et de génie industriel<br/>
# Polytechnique Montréal<br/>
#
# ## TD5 : Régression logistique pour prédire la survie des passagers du Titanic
#
# Pour ce concours, vous aurez accès aux caractéristiques des passagers du Titanic
#
# La liste des passagers a été scindé en deux groupes : un groupe d'entraînement (*Train.csv*) et un groupe de test (*Test.csv*). Les membres d'équipages sont ignorés. Le jeu de données d'entraînement doit être utilisé pour estimer les paramètres d'un modèle de régression logistique. Vous devrez trouver le meilleur modèle possible en faisant un choix judicieux des variables explicatives. Par la suite, votre modèle servira à prédire le sort des passagers de la liste de test.
#
# L'ensemble d'entraînement contient les informations de 872 passagers et leur sort (décès ou survie).
#
# L'ensemble de test contient seulement les informations de 437 passagers. Vous devez prédire pour chacun d'eux s'ils ont survécu ou non au naufrage.
#
# Avant d'exécuter ce code, vous devrez récupérer les informations sur les passagers du Titatnic déjà partitionnées en échantillon d'apprentissage et de test. Vous modèles pourront être entraînés sur les données *Train.csv* disponible sur la page GitHub du cours. Vos prédictions seront par la suite comparées au sort des passager de l'échantillon de test. Vous devrez déposer voter fichier de prédictions sur la [page Kaggle du TD5](https://www.kaggle.com/t/bf44db6f419f4e51a104cfc4d1546359).
#
# Dans ce code de base, on n'utilisera que la classe du passager pour prédire sont sort. **L'objectif de ce TD est d'améliorer le taux de bonnes prédictions en ajoutant des variables explicatives significatives.**
#
#
# ### Sommaire:
# ___
#
# 1. **[Chargement des données de l'ensemble d'entraînement](#section_1)**
# 2. **[Analyse exploratoire](#section_2)**
# 3. **[Modèle de régression logistique](#section_3)**
# 4. **[Prédiction de la survie des passagers de l'ensemble de test](#section_4)**
#     1. Chargement des données de l'ensemble de test
#     2. Estimation de la probabilité de survie de chacun des passagers de l'ensemble de test
#     3. Prédiction de la survie des passagers de l'ensemble de test
#     4. Préparation du fichier des préditions pour téléverser sur Kaggle

# %%
# Chargement des librairies nécessaires
using CSV, DataFrames, Gadfly, GLM, Distributions, LinearAlgebra

# %% [markdown]
# ---
# <a id="section_1"></a>
# ## 1. Chargement et traitement des données

# %%
data = CSV.read("Train.csv", DataFrame)

# Conversion en String pour que GLM considère la classe comme une variable qualitative
data[!, :Pclass] = string.(data[:, :Pclass])
dropmissing!(data, :Embarked)
# data[!, :Embarked] = string.(data[:, :Embarked])

first(data,5)
# Out:
# 5×12 DataFrame
#  Row │ PassengerId  Survived  Pclass  Name                             Sex     ⋯
#      │ Int64        Int64     String  String                           String7 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │           2         1  1       Kimball, Mr. Edwin Nelson Jr     male    ⋯
#    2 │           6         0  3       Minkoff, Mr. Lazar               male
#    3 │           7         1  2       Slayter, Miss. Hilda Mary        female
#    4 │          12         0  3       Zimmerman, Mr. Leo               male
#    5 │          14         0  3       Hagland, Mr. Ingvald Olai Olsen  male    ⋯
#                                                                7 columns omitted

# %% [markdown]
# ---
# <a id="section_2"></a>
# ## 2. Analyse exploratoire
#
# On souhaite vérifier s'il existe une relation entre la classe des passagers et leur taux de survie.

# %%
df = combine(groupby(data, :Pclass), :Survived => mean => Symbol("Taux de survie"))

# Permutation des colonnes pour mettre les classes dans le bon ordre pour le graphique
df = df[[1;3;2], :]  

plot(df, x=:Pclass, y=Symbol("Taux de survie"), Geom.bar)
# Out:
# Plot(...)

# %%
df = combine(groupby(data, :Sex), :Survived => mean => Symbol("Taux de survie"))
plot(df, x=:Sex, y=Symbol("Taux de survie"), Geom.bar)
# Out:
# Plot(...)

# %%
df_age = dropmissing(data, :Age)
plot(df_age, x=:Age, Geom.histogram)
# Out:
# Plot(...)

# %%
df = combine(groupby(data, :Parch), :Survived => mean => Symbol("Taux de survie"))
plot(df, x=:Parch, y=Symbol("Taux de survie"), Geom.bar)
# Out:
# Plot(...)

# %%
idxMissing = ismissing.(data[:, :Age])
ageMissing = data[idxMissing, :Age]
ageConnus = data[Not(idxMissing), :Age]
ageMoyen = mean(ageConnus)
ageMedian = median(ageConnus)

println(ageMoyen)
println(ageMedian)

data[idxMissing, :Age] .= ageMoyen
first(data, 5)
# Out:
# 29.793758967001434
# 28.0
# 5×12 DataFrame
#  Row │ PassengerId  Survived  Pclass  Name                             Sex     ⋯
#      │ Int64        Int64     String  String                           String7 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │           2         1  1       Kimball, Mr. Edwin Nelson Jr     male    ⋯
#    2 │           6         0  3       Minkoff, Mr. Lazar               male
#    3 │           7         1  2       Slayter, Miss. Hilda Mary        female
#    4 │          12         0  3       Zimmerman, Mr. Leo               male
#    5 │          14         0  3       Hagland, Mr. Ingvald Olai Olsen  male    ⋯
#                                                                7 columns omitted

# %%
df = combine(groupby(data, :Age), :Survived => mean => Symbol("Taux de survie"))

set_default_plot_size(20cm, 16cm)
plot(df, x=:Age, y=Symbol("Taux de survie"), Geom.smooth )
# Out:
# Plot(...)

# %%
function check_age(age)
    if 18 <= age < 70 #|| 55 <= age <70
        return "adulte"
    else
        return "vulnerable"
    end
end

function check_alone_sib(sib)
   if sib > 0
        return 0
    else
        return 1
    end
end

function check_alone_par(par)
   if par > 0
        return 0
    else
        return 1
    end
end

function last_to_embark(port)
   return port == "C" ? 0 : 1 
end
# Out:
# last_to_embark (generic function with 1 method)

# %%
data[!, :Age_Categ] = check_age.(data[:, :Age])
data[!, :IsAlone] = check_alone_sib.(data[:, :Parch])
data[!, :LastToEmbark] = last_to_embark.(data[:, :Embarked])

df = combine(groupby(data, [:Age_Categ]), :Survived => mean => Symbol("Taux de survie"))

plot(df, x=:Age_Categ, y=Symbol("Taux de survie"), Geom.bar)
# Out:
# Plot(...)

# %%
df = combine(groupby(data, :LastToEmbark), :Survived => mean => Symbol("Taux de survie"))

plot(df, x=:LastToEmbark, y=Symbol("Taux de survie"), Geom.bar)
# Out:
# Plot(...)

# %%
# filter(row -> ismissing(row.Embarked), data)
# dropmissing(data, :Embarked)

# gdf = groupby(data, :Embarked)

df = combine(groupby(data, :Embarked), :Survived => mean => Symbol("Taux de survie"))

plot(df, x=:Embarked, y=Symbol("Taux de survie"), Geom.bar)
# Out:
# Plot(...)

# %%
df = combine(groupby(data, [:IsAlone]), :Survived => mean => Symbol("Taux de survie"))

plot(df, x=:IsAlone, y=Symbol("Taux de survie"), Geom.bar)
# Out:
# Plot(...)

# %% [markdown]
# ---
# <a id="section_3"></a>
# ## 3. Modèle de régression logistique
#
# La classe des passagers est utilisée comme variable explicative de la probabilité de survie. La fonction de lien logit est utlisée.

# %%
M = glm(@formula(Survived ~ Pclass + LastToEmbark + Sex + Age_Categ), data,  Bernoulli(), LogitLink())
# Out:
# StatsModels.TableRegressionModel{GeneralizedLinearModel{GLM.GlmResp{Vector{Float64}, Bernoulli{Float64}, LogitLink}, GLM.DensePredChol{Float64, Cholesky{Float64, Matrix{Float64}}}}, Matrix{Float64}}
#
# Survived ~ 1 + Pclass + LastToEmbark + Sex + Age_Categ + IsAlone
#
# Coefficients:
# ─────────────────────────────────────────────────────────────────────────────────────
#                             Coef.  Std. Error       z  Pr(>|z|)  Lower 95%  Upper 95%
# ─────────────────────────────────────────────────────────────────────────────────────
# (Intercept)             2.42872      0.291904    8.32    <1e-16   1.8566     3.00084
# Pclass: 2              -0.890124     0.258276   -3.45    0.0006  -1.39634   -0.383912
# Pclass: 3              -1.76537      0.228307   -7.73    <1e-13  -2.21284   -1.31789
# LastToEmbark           -0.562893     0.219453   -2.56    0.0103  -0.993013  -0.132773
# Sex: male              -2.55855      0.189431  -13.51    <1e-40  -2.92982   -2.18727
# Age_Categ: vulnerable   0.856041     0.280404    3.05    0.0023   0.306459   1.40562
# IsAlone                 0.0927816    0.223115    0.42    0.6775  -0.344516   0.530079
# ─────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ---
# <a id="section_4"></a>
# ## 4. Prédiction de la survie des passagers de l'ensemble de test

# %% [markdown]
# ### 4.1 Chargement des données de l'ensemble de test

# %%
# Charger le jeu de données de test
test = CSV.read("Test.csv", DataFrame);

# Conversion en String pour que GLM considère la classe comme une variable qualitative
test[!, :Pclass] = string.(test[:, :Pclass]);  

idxMissing = ismissing.(test[:, :Age])
ageMissing = test[idxMissing, :Age]
ageConnus = test[Not(idxMissing), :Age]
ageMoyen = mean(ageConnus)
ageMedian = median(ageConnus)

# println(ageMoyen)
# println(ageMedian)

test[idxMissing, :Age] .= ageMoyen
first(test, 5)
# Out:
# 5×11 DataFrame
#  Row │ PassengerId  Pclass  Name                               Sex      Age    ⋯
#      │ Int64        String  String                             String7  Float6 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │           1  1       Kenyon, Mrs. Frederick R (Marion)  female    30.03 ⋯
#    2 │           3  3       Lockyer, Mr. Edward                male      30.03
#    3 │           4  3       Saad, Mr. Amin                     male      30.03
#    4 │           5  3       Johansson, Mr. Nils                male      29.0
#    5 │           8  1       Rowe, Mr. Alfred G                 male      33.0  ⋯
#                                                                7 columns omitted

# %% [markdown]
# ### 4.2 Estimation de la probabilité de survie de chacun des passagers de l'ensemble de test

# %%
θ̂ = predict(M, test)
# Out:
# 437-element Vector{Union{Missing, Float64}}:
#  0.8776235495556366
#  0.09467588468598326
#  0.15962898493076128
#  0.09467588468598326
#  0.3591997318884676
#  0.7550767158539942
#  0.3591997318884676
#  0.09467588468598326
#  0.7550767158539942
#  0.8923548216594378
#  0.9287045593443618
#  0.09467588468598326
#  0.3591997318884676
#  ⋮
#  0.09467588468598326
#  0.09467588468598326
#  0.5045006972262075
#  0.7084697963877709
#  0.7550767158539942
#  0.5722706268997442
#  0.1941790821132439
#  0.7084697963877709
#  0.09467588468598326
#  0.5722706268997442
#  0.7550767158539942
#  0.1941790821132439

# %% [markdown]
# ### 4.3 Prédiction de la survie des passagers de l'ensemble de test

# %%
# Prédiction de la survie pour chacun des passagers de l'échantillon de test
Ŷ = zeros(Int64, size(test,1))
Ŷ[θ̂.>.5] .= 1;
# Out:
# ArgumentError: unable to check bounds for indices of type Missing
#
# Stacktrace:
#   [1] checkindex(#unused#::Type{Bool}, inds::Base.OneTo{Int64}, i::Missing)
#     @ Base .\abstractarray.jl:725
#   [2] checkindex
#     @ .\abstractarray.jl:740 [inlined]
#   [3] checkbounds
#     @ .\abstractarray.jl:653 [inlined]
#   [4] checkbounds
#     @ .\abstractarray.jl:668 [inlined]
#   [5] view
#     @ .\subarray.jl:177 [inlined]
#   [6] maybeview
#     @ .\views.jl:146 [inlined]
#   [7] dotview(::Vector{Int64}, ::Vector{Union{Missing, Bool}})
#     @ Base.Broadcast .\broadcast.jl:1201
#   [8] top-level scope
#     @ In[212]:3
#   [9] eval
#     @ .\boot.jl:368 [inlined]
#  [10] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base .\loading.jl:1428

# %% [markdown]
# ### 4.4 Préparation du fichier des préditions pour téléverser sur Kaggle

# %%
# Enregistrement dans un fichier CSV pour soumission sur Kaggle
# Première colonne : identifiant des passagers
# Deuxième colonne : survie = 1, décès = 0 (nombres entiers)

prediction = DataFrame(PassengerId = test[:,:PassengerId], Survived = Ŷ)
CSV.write("benchmark_predictions.csv", prediction)
# Out:
# "benchmark_predictions.csv"

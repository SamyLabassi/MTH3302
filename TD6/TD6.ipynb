# %% [markdown]
# # MTH3302 : Méthodes probabilistes et statistiques pour l'I.A.
#
# Jonathan Jalbert<br/>
# Professeur agrégé au Département de mathématiques et de génie industriel<br/>
# Polytechnique Montréal<br/>
#
# Les images proviennent du jeu de données publiques *The Extended Yale Face Database B* disponible sur le site http://vision.ucsd.edu/~iskwak/ExtYaleDatabase/ExtYaleB.html.
#
#
# ## TD6 : Reconnaissance faciale avec l'analyse en composantes principales
#
#
# Nous utiliserons des images récupérées de la base de données publique de Yale$^{(1)}$ que vous pouvez trouver sur Moodle. Nous avons choisi les 2 ensembles de telle sorte que l'ensemble de test contienne à la fois des images déjà vues et d'autres tout-à-fait nouvelles. L'objectif final est de mesurer la performance de notre algorithme en comptant le nombre d'exemples bien classifiés.
#
# Plusieurs librairies que nous n'utilisons pas régulièrement dans le cours sont nécessaire. Exécutez la prochaine cellule de code pour installer ces librairies.

# %%
import Pkg
Pkg.add(["Images", "Netpbm", "ImageMagick", "Colors"])
# Out:
#     Updating registry at `C:\Users\samyt\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed JpegTurbo_jll ───────────── v2.1.2+0
#    Installed ImageIO ─────────────────── v0.6.6
#    Installed ImageSegmentation ───────── v1.7.0
#    Installed TiledIteration ──────────── v0.3.1
#    Installed AxisArrays ──────────────── v0.4.6
#    Installed TiffImages ──────────────── v0.6.1
#    Installed PNGFiles ────────────────── v0.3.16
#    Installed JpegTurbo ───────────────── v0.1.1
#    Installed LERC_jll ────────────────── v3.0.0+1
#    Installed ImageMagick ─────────────── v1.2.2
#    Installed ProgressMeter ───────────── v1.7.2
#    Installed Sixel ───────────────────── v0.1.2
#    Installed RegionTrees ─────────────── v0.3.2
#    Installed NearestNeighbors ────────── v0.4.12
#    Installed OpenEXR ─────────────────── v0.3.2
#    Installed Images ──────────────────── v0.25.2
#    Installed Netpbm ──────────────────── v1.0.2
#    Installed FileIO ──────────────────── v1.15.0
#    Installed MetaGraphs ──────────────── v0.7.1
#    Installed ArnoldiMethod ───────────── v0.2.0
#    Installed CEnum ───────────────────── v0.4.2
#    Installed PkgVersion ──────────────── v0.3.2
#    Installed QOI ─────────────────────── v1.0.0
#    Installed CustomUnitRanges ────────── v1.0.2
#    Installed Clustering ──────────────── v0.14.3
#    Installed ImageMetadata ───────────── v0.9.8
#    Installed Graphics ────────────────── v1.1.2
#    Installed ComputationalResources ──── v0.3.2
#    Installed ImageFiltering ──────────── v0.7.2
#    Installed CatIndices ──────────────── v0.2.2
#    Installed ImageContrastAdjustment ─── v0.3.10
#    Installed ImageMagick_jll ─────────── v6.9.10-12+3
#    Installed MappedArrays ────────────── v0.4.1
#    Installed PaddedViews ─────────────── v0.5.11
#    Installed MosaicViews ─────────────── v0.3.3
#    Installed libpng_jll ──────────────── v1.6.38+0
#    Installed LazyModules ─────────────── v0.3.1
#    Installed Graphs ──────────────────── v1.7.4
#    Installed ImageTransformations ────── v0.9.5
#    Installed ImageCore ───────────────── v0.9.4
#    Installed TensorCore ──────────────── v0.1.1
#    Installed Zstd_jll ────────────────── v1.5.2+0
#    Installed Inflate ─────────────────── v0.1.3
#    Installed ImageShow ───────────────── v0.3.6
#    Installed ImageQualityIndexes ─────── v0.3.3
#    Installed Imath_jll ───────────────── v3.1.2+0
#    Installed Libtiff_jll ─────────────── v4.4.0+0
#    Installed IntegralArrays ──────────── v0.1.5
#    Installed StackViews ──────────────── v0.1.1
#    Installed ColorVectorSpace ────────── v0.9.9
#    Installed CoordinateTransformations ─ v0.6.2
#    Installed RangeArrays ─────────────── v0.3.2
#    Installed Quaternions ─────────────── v0.5.7
#    Installed Rotations ───────────────── v1.3.2
#    Installed UnPack ──────────────────── v1.0.2
#    Installed OpenEXR_jll ─────────────── v3.1.1+0
#    Installed libsixel_jll ────────────── v1.10.3+0
#    Installed SimpleWeightedGraphs ────── v1.2.1
#    Installed SimpleTraits ────────────── v0.9.4
#    Installed ImageBase ───────────────── v0.1.5
#    Installed IntervalSets ────────────── v0.7.3
#    Installed ImageDistances ──────────── v0.2.16
#    Installed JLD2 ────────────────────── v0.4.24
#    Installed ImageAxes ───────────────── v0.6.10
#    Installed FFTViews ────────────────── v0.3.2
#    Installed Parameters ──────────────── v0.12.3
#    Installed ImageMorphology ─────────── v0.3.2
#     Updating `C:\Users\samyt\.julia\environments\v1.8\Project.toml`
#   [5ae59095] + Colors v0.12.8
#   [6218d12a] + ImageMagick v1.2.2
#   [916415d5] + Images v0.25.2
#   [f09324ee] + Netpbm v1.0.2
#     Updating `C:\Users\samyt\.julia\environments\v1.8\Manifest.toml`
#   [ec485272] + ArnoldiMethod v0.2.0
#   [39de3d68] + AxisArrays v0.4.6
#   [fa961155] + CEnum v0.4.2
#   [aafaddc9] + CatIndices v0.2.2
#   [aaaa29a8] + Clustering v0.14.3
#   [c3611d14] + ColorVectorSpace v0.9.9
#   [ed09eef8] + ComputationalResources v0.3.2
#   [150eb455] + CoordinateTransformations v0.6.2
#   [dc8bdbbb] + CustomUnitRanges v1.0.2
#   [4f61f5a4] + FFTViews v0.3.2
#   [5789e2e9] + FileIO v1.15.0
#   [a2bd30eb] + Graphics v1.1.2
#   [86223c79] + Graphs v1.7.4
#   [2803e5a7] + ImageAxes v0.6.10
#   [c817782e] + ImageBase v0.1.5
#   [f332f351] + ImageContrastAdjustment v0.3.10
#   [a09fc81d] + ImageCore v0.9.4
#   [51556ac3] + ImageDistances v0.2.16
#   [6a3955dd] + ImageFiltering v0.7.2
#   [82e4d734] + ImageIO v0.6.6
#   [6218d12a] + ImageMagick v1.2.2
#   [bc367c6b] + ImageMetadata v0.9.8
# ⌅ [787d08f9] + ImageMorphology v0.3.2
#   [2996bd0c] + ImageQualityIndexes v0.3.3
#   [80713f31] + ImageSegmentation v1.7.0
#   [4e3cecfd] + ImageShow v0.3.6
#   [02fcd773] + ImageTransformations v0.9.5
#   [916415d5] + Images v0.25.2
#   [d25df0c9] + Inflate v0.1.3
#   [1d092043] + IntegralArrays v0.1.5
#   [8197267c] + IntervalSets v0.7.3
#   [033835bb] + JLD2 v0.4.24
#   [b835a17e] + JpegTurbo v0.1.1
#   [8cdb02fc] + LazyModules v0.3.1
#   [dbb5928d] + MappedArrays v0.4.1
#   [626554b9] + MetaGraphs v0.7.1
#   [e94cdb99] + MosaicViews v0.3.3
#   [b8a86587] + NearestNeighbors v0.4.12
#   [f09324ee] + Netpbm v1.0.2
#   [52e1d378] + OpenEXR v0.3.2
#   [f57f5aa1] + PNGFiles v0.3.16
#   [5432bcbf] + PaddedViews v0.5.11
#   [d96e819e] + Parameters v0.12.3
#   [eebad327] + PkgVersion v0.3.2
#   [92933f4c] + ProgressMeter v1.7.2
#   [4b34888f] + QOI v1.0.0
#   [94ee1d12] + Quaternions v0.5.7
#   [b3c3ace0] + RangeArrays v0.3.2
#   [dee08c22] + RegionTrees v0.3.2
#   [6038ab10] + Rotations v1.3.2
#   [699a6c99] + SimpleTraits v0.9.4
#   [47aef6b3] + SimpleWeightedGraphs v1.2.1
#   [45858cf5] + Sixel v0.1.2
#   [cae243ae] + StackViews v0.1.1
#   [62fd8b95] + TensorCore v0.1.1
#   [731e570b] + TiffImages v0.6.1
# ⌅ [06e1c1a7] + TiledIteration v0.3.1
#   [3a884ed6] + UnPack v1.0.2
# ⌅ [c73af94c] + ImageMagick_jll v6.9.10-12+3
#   [905a6f67] + Imath_jll v3.1.2+0
#   [aacddb02] + JpegTurbo_jll v2.1.2+0
#   [88015f11] + LERC_jll v3.0.0+1
#   [89763e89] + Libtiff_jll v4.4.0+0
#   [18a262bb] + OpenEXR_jll v3.1.1+0
#   [3161d3a3] + Zstd_jll v1.5.2+0
#   [b53b4c65] + libpng_jll v1.6.38+0
#   [075b6546] + libsixel_jll v1.10.3+0
#         Info Packages marked with ⌅ have new versions available but cannot be upgraded. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ RangeArrays
#   ✓ UnPack
#   ✓ LazyModules
#   ✓ Inflate
#   ✓ IntervalSets
#   ✓ TensorCore
#   ✓ CustomUnitRanges
#   ✓ ComputationalResources
#   ✓ CEnum
#   ✓ PkgVersion
#   ✓ ProgressMeter
#   ✓ MappedArrays
#   ✓ PaddedViews
#   ✓ StackViews
#   ✓ TiledIteration
#   ✓ SimpleTraits
#   ✓ Graphics
#   ✓ FileIO
#   ✓ NearestNeighbors
#   ✓ CoordinateTransformations
#   ✓ JpegTurbo_jll
#   ✓ ArnoldiMethod
#   ✓ libpng_jll
#   ✓ Zstd_jll
#   ✓ RegionTrees
#   ✓ Imath_jll
#   ✓ LERC_jll
#   ✓ Parameters
#   ✓ Quaternions
#   ✓ IntegralArrays
#   ✓ AxisArrays
#   ✓ FFTViews
#   ✓ CatIndices
#   ✓ MosaicViews
#   ✓ QOI
#   ✓ ColorVectorSpace
#   ✓ Clustering
#   ✓ libsixel_jll
#   ✓ OpenEXR_jll
#   ✓ Libtiff_jll
#   ✓ Graphs
#   ✓ Rotations
#   ✓ OpenEXR
#   ✓ ImageMagick_jll
#   ✓ SimpleWeightedGraphs
#   ✓ JLD2
#   ✓ MetaGraphs
#   ✓ ImageCore
#   ✓ ImageMorphology
#   ✓ Netpbm
#   ✓ ImageBase
#   ✓ PNGFiles
#   ✓ JpegTurbo
#   ✓ Sixel
#   ✓ ImageDistances
#   ✓ ImageMagick
#   ✓ TiffImages
#   ✓ ImageAxes
#   ✓ ImageIO
#   ✓ ImageShow
#   ✓ ImageTransformations
#   ✓ ImageMetadata
#   ✓ ImageContrastAdjustment
#   ✓ ImageFiltering
#   ✓ ImageQualityIndexes
#   ✓ ImageSegmentation
#   ✓ Images
#   67 dependencies successfully precompiled in 349 seconds. 103 already precompiled.

# %%
# Librairies standards du cours
using Statistics, LinearAlgebra, Gadfly, DataFrames

# Librairie pour le traitement des images
using Images, Netpbm, ImageMagick, Colors

# %% [markdown]
# # 1. Chargement des images d'entraînement
# ___
#
# Les images d'entraînement sont contenues dans le dossier *Train* du jeu de données que vous pouvez récupérer sur Moodle. L'ensemble d'entraînement est constitué de 784 images provenant de 28 personnes différente, soit de 28 images par personne.
#
# Les images sont des visages déjà correctement alignés, ce qui nous permet de nous concentrer directemement sur la reconnaissance des visages.

# %%
# Récupération de tous les noms de fichiers de l'échantillon d'entraînement
file = readdir("Train")
trainFileName = ["Train/"*file[i] for i=1:length(file)];

# %%
# Affichage des 8 photos de la première personne
load.(trainFileName[1:8])
# Out:
# 8-element Vector{Matrix{Gray{N0f8}}}:
#  [Gray{N0f8}(0.314) Gray{N0f8}(0.314) … Gray{N0f8}(0.263) Gray{N0f8}(0.278); Gray{N0f8}(0.318) Gray{N0f8}(0.31) … Gray{N0f8}(0.239) Gray{N0f8}(0.251); … ; Gray{N0f8}(0.047) Gray{N0f8}(0.047) … Gray{N0f8}(0.055) Gray{N0f8}(0.055); Gray{N0f8}(0.047) Gray{N0f8}(0.047) … Gray{N0f8}(0.047) Gray{N0f8}(0.043)]
#  [Gray{N0f8}(0.369) Gray{N0f8}(0.369) … Gray{N0f8}(0.298) Gray{N0f8}(0.31); Gray{N0f8}(0.341) Gray{N0f8}(0.341) … Gray{N0f8}(0.282) Gray{N0f8}(0.294); … ; Gray{N0f8}(0.02) Gray{N0f8}(0.027) … Gray{N0f8}(0.031) Gray{N0f8}(0.035); Gray{N0f8}(0.016) Gray{N0f8}(0.027) … Gray{N0f8}(0.027) Gray{N0f8}(0.031)]
#  [Gray{N0f8}(0.231) Gray{N0f8}(0.259) … Gray{N0f8}(0.263) Gray{N0f8}(0.227); Gray{N0f8}(0.263) Gray{N0f8}(0.298) … Gray{N0f8}(0.282) Gray{N0f8}(0.282); … ; Gray{N0f8}(0.016) Gray{N0f8}(0.02) … Gray{N0f8}(0.02) Gray{N0f8}(0.024); Gray{N0f8}(0.012) Gray{N0f8}(0.016) … Gray{N0f8}(0.027) Gray{N0f8}(0.027)]
#  [Gray{N0f8}(0.271) Gray{N0f8}(0.278) … Gray{N0f8}(0.212) Gray{N0f8}(0.216); Gray{N0f8}(0.263) Gray{N0f8}(0.271) … Gray{N0f8}(0.212) Gray{N0f8}(0.22); … ; Gray{N0f8}(0.118) Gray{N0f8}(0.129) … Gray{N0f8}(0.09) Gray{N0f8}(0.098); Gray{N0f8}(0.122) Gray{N0f8}(0.122) … Gray{N0f8}(0.09) Gray{N0f8}(0.102)]
#  [Gray{N0f8}(0.208) Gray{N0f8}(0.204) … Gray{N0f8}(0.157) Gray{N0f8}(0.149); Gray{N0f8}(0.204) Gray{N0f8}(0.2) … Gray{N0f8}(0.18) Gray{N0f8}(0.169); … ; Gray{N0f8}(0.157) Gray{N0f8}(0.161) … Gray{N0f8}(0.082) Gray{N0f8}(0.102); Gray{N0f8}(0.145) Gray{N0f8}(0.161) … Gray{N0f8}(0.098) Gray{N0f8}(0.102)]
#  [Gray{N0f8}(0.416) Gray{N0f8}(0.42) … Gray{N0f8}(0.251) Gray{N0f8}(0.22); Gray{N0f8}(0.4) Gray{N0f8}(0.42) … Gray{N0f8}(0.251) Gray{N0f8}(0.227); … ; Gray{N0f8}(0.043) Gray{N0f8}(0.043) … Gray{N0f8}(0.031) Gray{N0f8}(0.035); Gray{N0f8}(0.031) Gray{N0f8}(0.035) … Gray{N0f8}(0.035) Gray{N0f8}(0.035)]
#  [Gray{N0f8}(0.467) Gray{N0f8}(0.467) … Gray{N0f8}(0.2) Gray{N0f8}(0.165); Gray{N0f8}(0.463) Gray{N0f8}(0.471) … Gray{N0f8}(0.2) Gray{N0f8}(0.184); … ; Gray{N0f8}(0.098) Gray{N0f8}(0.102) … Gray{N0f8}(0.027) Gray{N0f8}(0.031); Gray{N0f8}(0.094) Gray{N0f8}(0.082) … Gray{N0f8}(0.031) Gray{N0f8}(0.031)]
#  [Gray{N0f8}(0.353) Gray{N0f8}(0.353) … Gray{N0f8}(0.133) Gray{N0f8}(0.137); Gray{N0f8}(0.353) Gray{N0f8}(0.353) … Gray{N0f8}(0.118) Gray{N0f8}(0.141); … ; Gray{N0f8}(0.169) Gray{N0f8}(0.145) … Gray{N0f8}(0.051) Gray{N0f8}(0.051); Gray{N0f8}(0.173) Gray{N0f8}(0.161) … Gray{N0f8}(0.055) Gray{N0f8}(0.051)]

# %%
# Affichage des 8 photos de la huitième personne
load.(trainFileName[29:36])
# Out:
# 8-element Vector{Matrix{Gray{N0f8}}}:
#  [Gray{N0f8}(0.337) Gray{N0f8}(0.333) … Gray{N0f8}(0.388) Gray{N0f8}(0.384); Gray{N0f8}(0.31) Gray{N0f8}(0.314) … Gray{N0f8}(0.38) Gray{N0f8}(0.376); … ; Gray{N0f8}(0.286) Gray{N0f8}(0.306) … Gray{N0f8}(0.337) Gray{N0f8}(0.325); Gray{N0f8}(0.282) Gray{N0f8}(0.298) … Gray{N0f8}(0.333) Gray{N0f8}(0.322)]
#  [Gray{N0f8}(0.376) Gray{N0f8}(0.392) … Gray{N0f8}(0.396) Gray{N0f8}(0.396); Gray{N0f8}(0.376) Gray{N0f8}(0.373) … Gray{N0f8}(0.392) Gray{N0f8}(0.392); … ; Gray{N0f8}(0.204) Gray{N0f8}(0.224) … Gray{N0f8}(0.239) Gray{N0f8}(0.227); Gray{N0f8}(0.2) Gray{N0f8}(0.212) … Gray{N0f8}(0.235) Gray{N0f8}(0.224)]
#  [Gray{N0f8}(0.38) Gray{N0f8}(0.388) … Gray{N0f8}(0.373) Gray{N0f8}(0.373); Gray{N0f8}(0.373) Gray{N0f8}(0.38) … Gray{N0f8}(0.369) Gray{N0f8}(0.365); … ; Gray{N0f8}(0.129) Gray{N0f8}(0.133) … Gray{N0f8}(0.137) Gray{N0f8}(0.133); Gray{N0f8}(0.133) Gray{N0f8}(0.141) … Gray{N0f8}(0.133) Gray{N0f8}(0.141)]
#  [Gray{N0f8}(0.263) Gray{N0f8}(0.271) … Gray{N0f8}(0.329) Gray{N0f8}(0.345); Gray{N0f8}(0.255) Gray{N0f8}(0.247) … Gray{N0f8}(0.322) Gray{N0f8}(0.333); … ; Gray{N0f8}(0.345) Gray{N0f8}(0.357) … Gray{N0f8}(0.431) Gray{N0f8}(0.42); Gray{N0f8}(0.337) Gray{N0f8}(0.345) … Gray{N0f8}(0.431) Gray{N0f8}(0.42)]
#  [Gray{N0f8}(0.165) Gray{N0f8}(0.161) … Gray{N0f8}(0.247) Gray{N0f8}(0.275); Gray{N0f8}(0.157) Gray{N0f8}(0.149) … Gray{N0f8}(0.247) Gray{N0f8}(0.263); … ; Gray{N0f8}(0.349) Gray{N0f8}(0.357) … Gray{N0f8}(0.435) Gray{N0f8}(0.416); Gray{N0f8}(0.341) Gray{N0f8}(0.353) … Gray{N0f8}(0.424) Gray{N0f8}(0.416)]
#  [Gray{N0f8}(0.4) Gray{N0f8}(0.416) … Gray{N0f8}(0.369) Gray{N0f8}(0.388); Gray{N0f8}(0.4) Gray{N0f8}(0.404) … Gray{N0f8}(0.369) Gray{N0f8}(0.376); … ; Gray{N0f8}(0.286) Gray{N0f8}(0.29) … Gray{N0f8}(0.286) Gray{N0f8}(0.271); Gray{N0f8}(0.278) Gray{N0f8}(0.294) … Gray{N0f8}(0.275) Gray{N0f8}(0.267)]
#  [Gray{N0f8}(0.357) Gray{N0f8}(0.369) … Gray{N0f8}(0.325) Gray{N0f8}(0.345); Gray{N0f8}(0.357) Gray{N0f8}(0.357) … Gray{N0f8}(0.325) Gray{N0f8}(0.329); … ; Gray{N0f8}(0.373) Gray{N0f8}(0.392) … Gray{N0f8}(0.376) Gray{N0f8}(0.353); Gray{N0f8}(0.369) Gray{N0f8}(0.384) … Gray{N0f8}(0.369) Gray{N0f8}(0.353)]
#  [Gray{N0f8}(0.431) Gray{N0f8}(0.447) … Gray{N0f8}(0.318) Gray{N0f8}(0.349); Gray{N0f8}(0.431) Gray{N0f8}(0.439) … Gray{N0f8}(0.322) Gray{N0f8}(0.329); … ; Gray{N0f8}(0.404) Gray{N0f8}(0.408) … Gray{N0f8}(0.298) Gray{N0f8}(0.282); Gray{N0f8}(0.392) Gray{N0f8}(0.404) … Gray{N0f8}(0.286) Gray{N0f8}(0.275)]

# %%
"""
    imgrayconvert(imageFileName ; columnStack=true ; T=Int64)

Conversion en intensité de gris de l'image du fichier `imageFileName`.

### Arguments
- `imageFileName::string` : le nom du fichier de l'image
- `columnStack::bool=true` : Si `true`, l'image est renvoyée comme un vecteur colonne (option par défaut) 
                             sinon la fonction renvoie la matrice des niveaux de gris.
- `T::DataType=Int64` : Type des éléments de la matrice (Int64 par défaut).

### Details
 
La fonction retourne la matrice ou le vecteur colonne des niveaux de gris.
 
### Examples

\```
 julia> imgrayconvert(imageFileName)
 julia> imgrayconvert(imageFileName ; columnStack=false)
 julia> imgrayconvert(imageFileName ; T=Float64)
\```

"""
function imgrayconvert(imageFileName::String ; columnStack::Bool=true)
    im = load(imageFileName)
    X = Float64.(im)
    if columnStack
        Y = X[:]
    else
        Y = X
    end
    return Y
end
# Out:
# imgrayconvert

# %%
"""
    imshow(X), imshow(X, im_size)

Affiche une matrice ou un vecteur en une image composée de niveau de gris.

### Arguments
- `X::Array{Real}` : Une matrice ou un vecteur colonne à afficher.
- `im_size::Tuple{Int64,Int64}` : Un tuple de Int64 indicant la taille de l'image. 


### Details

L'argument `im_size` n'est nécessaire que si un vecteur colonne est envoyé comme image.

L'échelle des niveaux de gris est ajustée en fonction des valeurs contenues dans X.
 
### Examples

\```
 julia> imshow(X)
 julia> imshow(X, (m₁, m₂))
\```

"""
function imshow(X::Array{<:Real,1}, im_size::Tuple{Int64,Int64})
    
    # scale the eigenvector for display on grayscale
    m = minimum(X)
    M = maximum(X)
    
    Z = (X .- m) / (M-m)
    
    Z = reshape(Z, im_size)

    Gray.(Z)
    
end

function imshow(X::Array{<:Real,2})
    
    # scale the eigenvector for display on grayscale
    m = minimum(X)
    M = maximum(X)
    
    Z = (X .- m) / (M-m)
    
    Gray.(Z)
    
end
# Out:
# imshow (generic function with 2 methods)

# %%
# Chargement des images de l'ensemble d'entrainement. Chaque image correspond à une ligne de la matrice X, 
# chaque pixel à une colonne.

n = length(trainFileName)

im = imgrayconvert(trainFileName[1],columnStack=false)
m₁, m₂ = size(im)
m = m₁ * m₂

X = Array{Float64,2}(undef,n,m)

for i=1:n
   X[i,:] = imgrayconvert(trainFileName[i], columnStack=true) 
end

# %%
imshow(X[1,:], (m₁, m₂))
# Out:
# 192×168 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.299578)   …  Gray{Float64}(0.261603)
#  Gray{Float64}(0.303797)      Gray{Float64}(0.232068)
#  Gray{Float64}(0.299578)      Gray{Float64}(0.223629)
#  Gray{Float64}(0.295359)      Gray{Float64}(0.227848)
#  Gray{Float64}(0.299578)      Gray{Float64}(0.227848)
#  Gray{Float64}(0.308017)   …  Gray{Float64}(0.21519)
#  Gray{Float64}(0.295359)      Gray{Float64}(0.206751)
#  Gray{Float64}(0.299578)      Gray{Float64}(0.198312)
#  Gray{Float64}(0.312236)      Gray{Float64}(0.202532)
#  Gray{Float64}(0.308017)      Gray{Float64}(0.206751)
#  Gray{Float64}(0.291139)   …  Gray{Float64}(0.21097)
#  Gray{Float64}(0.303797)      Gray{Float64}(0.21097)
#  Gray{Float64}(0.308017)      Gray{Float64}(0.21519)
#  ⋮                         ⋱
#  Gray{Float64}(0.113924)   …  Gray{Float64}(0.0843882)
#  Gray{Float64}(0.0886076)     Gray{Float64}(0.092827)
#  Gray{Float64}(0.0759494)     Gray{Float64}(0.0801688)
#  Gray{Float64}(0.0759494)     Gray{Float64}(0.0759494)
#  Gray{Float64}(0.0506329)     Gray{Float64}(0.113924)
#  Gray{Float64}(0.0506329)  …  Gray{Float64}(0.0675105)
#  Gray{Float64}(0.0464135)     Gray{Float64}(0.0421941)
#  Gray{Float64}(0.0464135)     Gray{Float64}(0.0337553)
#  Gray{Float64}(0.0421941)     Gray{Float64}(0.0168776)
#  Gray{Float64}(0.0126582)     Gray{Float64}(0.021097)
#  Gray{Float64}(0.0126582)  …  Gray{Float64}(0.021097)
#  Gray{Float64}(0.0126582)     Gray{Float64}(0.00843882)

# %% [markdown]
# # 2. Analyse en composantes principales
#
# Le but de cette section est de réduire la dimension du jeu de données d'entraînement. Nous ferons donc une décomposition en valeurs singulières de l'ensemble d'entraînement.
#
# Les étapes sont les suivantes :
# 1. Centrer chacune des lignes de la matrice des visages d'entraînement pour obtenir la matrice $Z$.
# 2. Effectuer une décomposition en valeurs singulières de $Z$.
# 3. Choisir le nombre de composantes principales requises $k$.

# %% [markdown]
# ## 2.1 Centrer les images de l'ensemble d'entraînement
#
# ### a) Calculez le visage moyen $\bar{X}$ en faisait une moyenne de tous les visages pour chacun des pixels. Affichez le visage moyen avec la fonction `imshow`.

# %%
X̄ = vec(mean(X, dims=1))
imshow(X̄, (m₁, m₂))
# Out:
# 192×168 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.23497)   …  Gray{Float64}(0.178705)
#  Gray{Float64}(0.236677)     Gray{Float64}(0.176594)
#  Gray{Float64}(0.236992)     Gray{Float64}(0.175201)
#  Gray{Float64}(0.233389)     Gray{Float64}(0.174743)
#  Gray{Float64}(0.229795)     Gray{Float64}(0.17512)
#  Gray{Float64}(0.229983)  …  Gray{Float64}(0.175857)
#  Gray{Float64}(0.231816)     Gray{Float64}(0.174509)
#  Gray{Float64}(0.234179)     Gray{Float64}(0.176549)
#  Gray{Float64}(0.233982)     Gray{Float64}(0.174114)
#  Gray{Float64}(0.230253)     Gray{Float64}(0.172128)
#  Gray{Float64}(0.226821)  …  Gray{Float64}(0.169648)
#  Gray{Float64}(0.225832)     Gray{Float64}(0.170879)
#  Gray{Float64}(0.225347)     Gray{Float64}(0.171086)
#  ⋮                        ⋱
#  Gray{Float64}(0.148147)  …  Gray{Float64}(0.103805)
#  Gray{Float64}(0.145532)     Gray{Float64}(0.0950806)
#  Gray{Float64}(0.143861)     Gray{Float64}(0.0904443)
#  Gray{Float64}(0.139683)     Gray{Float64}(0.0851161)
#  Gray{Float64}(0.138389)     Gray{Float64}(0.0801474)
#  Gray{Float64}(0.142154)  …  Gray{Float64}(0.0738578)
#  Gray{Float64}(0.158417)     Gray{Float64}(0.0698504)
#  Gray{Float64}(0.161625)     Gray{Float64}(0.0714318)
#  Gray{Float64}(0.157285)     Gray{Float64}(0.0699223)
#  Gray{Float64}(0.157366)     Gray{Float64}(0.0699852)
#  Gray{Float64}(0.156251)  …  Gray{Float64}(0.0789703)
#  Gray{Float64}(0.153421)     Gray{Float64}(0.085799)

# %% [markdown]
# ### b) Calculer la matrice $Z$ centrée des visages de l'ensemble d'entraînement. Ensuite, afficher la différence entre le premier visage  et le visage moyen avec la fonction `imshow`.

# %%
Z = X .- X̄'

imshow(Z[1,:], (m₁, m₂))
# Out:
# 192×168 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.386769)  Gray{Float64}(0.379335)  …  Gray{Float64}(0.382607)
#  Gray{Float64}(0.389884)  Gray{Float64}(0.374564)     Gray{Float64}(0.355066)
#  Gray{Float64}(0.38559)   Gray{Float64}(0.375267)     Gray{Float64}(0.347658)
#  Gray{Float64}(0.383582)  Gray{Float64}(0.385464)     Gray{Float64}(0.352036)
#  Gray{Float64}(0.389789)  Gray{Float64}(0.392143)     Gray{Float64}(0.351816)
#  Gray{Float64}(0.3979)    Gray{Float64}(0.412606)  …  Gray{Float64}(0.339055)
#  Gray{Float64}(0.384499)  Gray{Float64}(0.40006)      Gray{Float64}(0.331621)
#  Gray{Float64}(0.387231)  Gray{Float64}(0.390597)     Gray{Float64}(0.32221)
#  Gray{Float64}(0.399677)  Gray{Float64}(0.395577)     Gray{Float64}(0.327741)
#  Gray{Float64}(0.397742)  Gray{Float64}(0.394287)     Gray{Float64}(0.33301)
#  Gray{Float64}(0.383304)  Gray{Float64}(0.387986)  …  Gray{Float64}(0.338567)
#  Gray{Float64}(0.396212)  Gray{Float64}(0.397554)     Gray{Float64}(0.337849)
#  Gray{Float64}(0.400605)  Gray{Float64}(0.40212)      Gray{Float64}(0.341839)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.256576)  Gray{Float64}(0.250117)  …  Gray{Float64}(0.253676)
#  Gray{Float64}(0.233439)  Gray{Float64}(0.215142)     Gray{Float64}(0.266988)
#  Gray{Float64}(0.222084)  Gray{Float64}(0.199477)     Gray{Float64}(0.257362)
#  Gray{Float64}(0.224521)  Gray{Float64}(0.201888)     Gray{Float64}(0.256361)
#  Gray{Float64}(0.200614)  Gray{Float64}(0.201542)     Gray{Float64}(0.296253)
#  Gray{Float64}(0.198418)  Gray{Float64}(0.198386)  …  Gray{Float64}(0.254709)
#  Gray{Float64}(0.184818)  Gray{Float64}(0.182317)     Gray{Float64}(0.232386)
#  Gray{Float64}(0.182946)  Gray{Float64}(0.179234)     Gray{Float64}(0.223242)
#  Gray{Float64}(0.181368)  Gray{Float64}(0.165336)     Gray{Float64}(0.207682)
#  Gray{Float64}(0.152549)  Gray{Float64}(0.148685)     Gray{Float64}(0.211755)
#  Gray{Float64}(0.153199)  Gray{Float64}(0.148549)  …  Gray{Float64}(0.206513)
#  Gray{Float64}(0.15485)   Gray{Float64}(0.150179)     Gray{Float64}(0.190197)

# %% [markdown]
# ## 2.2 Décomposition en valeurs singulières de $Z$.
#
# ### a) Obtenez les matrices $U$ et $V$ ainsi que les valeurs singulières à l'aide de la fonction `svd` et/ou de la fonction `svdvals`.

# %%
U, S, V = svd(Z)
# Out:
# SVD{Float64, Float64, Matrix{Float64}, Vector{Float64}}
# U factor:
# 784×784 Matrix{Float64}:
#  -0.00853993  -0.0208504   -0.00191793   …  -0.0118739    -0.0357143
#  -0.0113704   -0.0279432    0.039592         0.00931866   -0.0357143
#  -0.0105211   -0.0172285    0.0887055        0.00332472   -0.0357143
#  -0.0019788   -0.00507491  -0.0354271       -0.0356094    -0.0357143
#   0.00882862   0.0268168   -0.0495356        0.012387     -0.0357143
#  -0.00516221  -0.0362772    0.0179528    …  -0.0237645    -0.0357143
#   0.00471402  -0.0461698   -0.00293838       0.00911858   -0.0357143
#   0.0125706   -0.0125162   -0.0349945       -0.0108606    -0.0357143
#   0.00791081  -0.0350513    0.0392738       -0.0171928    -0.0357143
#   0.0198981   -0.0266757    0.0182736        0.0266701    -0.0357143
#   0.0218109   -0.0126605   -0.0208385    …   0.0260296    -0.0357143
#   0.034971     0.0409686   -0.044485        -0.015093     -0.0357143
#   0.0304631    0.010677    -0.000612309     -0.027235     -0.0357143
#   ⋮                                      ⋱
#   0.0787515   -0.0332345   -0.0180464        0.00294747   -0.0357143
#  -0.0284438   -0.0134379    0.00219402       0.00676989   -0.0357143
#  -0.0437512   -0.0484615   -0.0516577        0.00639075   -0.0357143
#  -0.0373896   -0.00851029  -0.0654354    …   0.00794255   -0.0357143
#  -0.0678757   -0.0426675    0.0224717       -0.00737645   -0.0357143
#  -0.0844175   -0.0373101   -0.00571349       0.0132715    -0.0357143
#  -0.0577045   -0.0172807   -0.0496085       -0.0023838    -0.0357143
#  -0.0253124    0.0526222   -0.0765383        4.15853e-5   -0.0357143
#  -0.0812253   -0.00886514  -0.0303339    …  -0.00862461   -0.0357143
#  -0.0982289    0.0269565    0.00529406      -0.00413913   -0.0357143
#  -0.0814055    0.0367335    0.0543133        0.000259065  -0.0357143
#  -0.074539     0.0491561   -0.0628089        0.00218043   -0.0357143
# singular values:
# 784-element Vector{Float64}:
#  570.0650405668613
#  456.0139047119268
#  281.78864950406995
#  179.92513438891
#  167.54326774959526
#  147.04456933344494
#  142.84625506622064
#  129.57981381925114
#  111.09435034608487
#  106.23181252107136
#   98.22863329843695
#   94.51978831143607
#   85.19082650305756
#    ⋮
#    1.0672006470518143
#    1.0546397280467052
#    1.0447717840405937
#    1.0338974538288934
#    1.0175371246111433
#    1.001025895367171
#    0.9891414201377368
#    0.9818253254279525
#    0.9558767827776263
#    0.95317202825247
#    0.9256020301573415
#    3.986500324314894e-13
# Vt factor:
# 784×32256 Matrix{Float64}:
#   0.00534734    0.00540604    0.00544098   …  -0.00471819   -0.00487578
#  -0.00593475   -0.00593016   -0.00581651       0.000172073   0.000162291
#   0.000738375   0.000760127   0.000862511     -0.0045281    -0.00467062
#  -0.00190431   -0.00195788   -0.00232059       0.00561862    0.00714238
#   0.00665401    0.00672453    0.00691088       0.0031727     0.00294014
#  -0.0078692    -0.00775657   -0.00741756   …  -0.007295     -0.00692107
#  -0.00582486   -0.00554808   -0.00556005       0.00183732    0.00416406
#   0.00216331    0.00245346    0.00259157      -0.00314707   -0.00430989
#  -0.00885269   -0.00861888   -0.00807186       6.06916e-5    0.00040678
#   0.000866065   0.00083395    0.00109186      -0.00275238   -0.00156688
#  -0.000208028  -2.05641e-6    0.000817033  …   0.00529755    0.00437309
#   0.00271507    0.002577      0.00316097      -0.00560216   -0.00635418
#   0.00106514    0.000733711   0.000385696     -0.00866598   -0.00947056
#   ⋮                                        ⋱                 ⋮
#   0.0058027    -0.00232647   -0.00761454       0.00360912    0.00502217
#   0.00176569    0.00621969    0.00157276       0.00748216    0.00788647
#  -0.00314131   -0.00107335   -0.00235713       0.00220567    0.000431313
#  -0.00251509    0.0104746     0.00317714   …   0.0059202     0.00533761
#   0.000255823   0.00820218    0.00182759       0.00269609    0.00895113
#  -0.0026206    -0.00184749    0.00264534       0.00685454    0.0103462
#   0.000274555   0.000335544   0.00863844       0.00497689    0.00922432
#   0.000973193   0.000240897  -0.00256947       0.000759649   0.00501641
#   0.0076739     0.00456149   -0.0032081    …   0.0145134     0.00726978
#  -0.00460545   -0.000776361   0.00475892       0.0004055    -0.00183001
#   0.00224768    7.15268e-5    0.00156069       0.00683233   -0.00149391
#  -0.00281522    0.0206703    -0.0119578       -0.00194088   -0.00281066

# %% [markdown]
# ### b) Affichez les premiers vecteurs singuliers de $V$ avec la fonction `imshow`.
#
# Ces composantes représentent les modes de plus grande variabilité. Dans la reconnaissance faciale, elles sont appelées les *eigenfaces*.

# %%
imshow(V'[1,:], (m₁, m₂))
# Out:
# 192×168 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.910729)  Gray{Float64}(0.916495)  …  Gray{Float64}(0.201823)
#  Gray{Float64}(0.914178)  Gray{Float64}(0.919172)     Gray{Float64}(0.203365)
#  Gray{Float64}(0.91623)   Gray{Float64}(0.919054)     Gray{Float64}(0.204377)
#  Gray{Float64}(0.916396)  Gray{Float64}(0.917521)     Gray{Float64}(0.206656)
#  Gray{Float64}(0.915161)  Gray{Float64}(0.916185)     Gray{Float64}(0.207483)
#  Gray{Float64}(0.917404)  Gray{Float64}(0.917989)  …  Gray{Float64}(0.203762)
#  Gray{Float64}(0.919478)  Gray{Float64}(0.919378)     Gray{Float64}(0.206238)
#  Gray{Float64}(0.92252)   Gray{Float64}(0.924005)     Gray{Float64}(0.201446)
#  Gray{Float64}(0.924122)  Gray{Float64}(0.924398)     Gray{Float64}(0.20626)
#  Gray{Float64}(0.925104)  Gray{Float64}(0.922612)     Gray{Float64}(0.204591)
#  Gray{Float64}(0.922932)  Gray{Float64}(0.9198)    …  Gray{Float64}(0.206105)
#  Gray{Float64}(0.924881)  Gray{Float64}(0.921467)     Gray{Float64}(0.20396)
#  Gray{Float64}(0.924597)  Gray{Float64}(0.921109)     Gray{Float64}(0.202068)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.886632)  Gray{Float64}(0.883445)  …  Gray{Float64}(0.294765)
#  Gray{Float64}(0.886957)  Gray{Float64}(0.883927)     Gray{Float64}(0.306653)
#  Gray{Float64}(0.888894)  Gray{Float64}(0.88622)      Gray{Float64}(0.311275)
#  Gray{Float64}(0.884254)  Gray{Float64}(0.882598)     Gray{Float64}(0.315361)
#  Gray{Float64}(0.883987)  Gray{Float64}(0.883489)     Gray{Float64}(0.320022)
#  Gray{Float64}(0.887637)  Gray{Float64}(0.889505)  …  Gray{Float64}(0.324591)
#  Gray{Float64}(0.893478)  Gray{Float64}(0.891754)     Gray{Float64}(0.328806)
#  Gray{Float64}(0.893377)  Gray{Float64}(0.894876)     Gray{Float64}(0.32548)
#  Gray{Float64}(0.889155)  Gray{Float64}(0.893015)     Gray{Float64}(0.327711)
#  Gray{Float64}(0.887374)  Gray{Float64}(0.895567)     Gray{Float64}(0.329133)
#  Gray{Float64}(0.886517)  Gray{Float64}(0.896685)  …  Gray{Float64}(0.319414)
#  Gray{Float64}(0.887712)  Gray{Float64}(0.897096)     Gray{Float64}(0.310157)

# %% [markdown]
# ## 2.3 Choix du nombre $k$ de vecteurs singuliers à utiliser
#
# ### a) Tracez un graphique permettant de voir le pourcentage de la variance totale retenue en fonction du nombre de vecteur singuliers.

# %%
STotal = sum(S)
range = 1:length(S)
variances = [sum(S[1:i]) for i in range]

plot(x=range, y = variances ./ STotal, Geom.line)
# Out:
# Plot(...)

# %% [markdown]
# ### b) Calculez le pourcentage de la variance récupérée en utilisant 10, 50 et 70 composantes principales.

# %%
variances[10]/STotal
# Out:
# 0.26152214177351435

# %%
variances[50]/STotal
# Out:
# 0.510972821198919

# %%
variances[70]/STotal
# Out:
# 0.5749609297110408

# %% [markdown]
# # 3. Approximation d'une image à l'aide des vecteurs singuliers
#
# Soit $k$ le nombre de vecteurs singuliers retenus. Nous allons approximer le visage $\mathbf{z}_i$ à l'aide des $k$ premières vecteurs singuliers.
#
# Dénotons par $V_k$ la matrice des $k$ premiers vecteurs singuliers de $V$. On cherche à trouver la combinaison linéaire des $k$ vecteurs qui approxime le visage $\mathbf{z}_i$ :
#
# $$ \mathbf{Z}_i = V_k \mathbf{w} + \varepsilon ; $$
#
# où $\mathbf{w}$ correspond au vecteur des poids de la combinaison linéaire et $\varepsilon$ correspond à l'erreur que l'on fait. L'erreur serait nulle si on utilisait tous les vecteurs singuliers.
#
# On se retrouve donc dans un problème de régression où la variable d'intérêt est l'image du visage et où les variables explicatives sont les vecteur singuliers $V_k$. Pour trouver les coefficients de régression $\mathbf{w}$, il suffit de procéder comme au chapitre 2 :
#
# $$ \mathbf{\hat{w}} = (V_k^\top V_k)^{-1} V_k^\top \mathbf{z}_i . $$
#
# Or, puisque la matrice des vecteurs singuliers est orthonormales, la dernière équation se simplifie à l'expression suivante :
#
# $$ \mathbf{\hat{w}} = V_k^\top \mathbf{z}_i . $$
#
# Le visage $\mathbf{z}_i$ projeté dans les k premières composantes principales, dénoté par $\mathbf{\hat{z}}_i$,  est obtenue avec l'équation suivante :
#
# $$ \mathbf{\hat{z}}_i = V_k \mathbf{\hat{w}}.$$
#
#
#
# **Remarque :** On pourrait être de tenté de calculer la projection du visage en une seule étape, en remplaçant $\mathbf{w}$ par son expression :
#
# $$ \mathbf{\hat{z}}_i = V_k \mathbf{\hat{w}} = V_k V_k^\top \mathbf{z}^\top_i.$$
#
# La matrice $V_k V_k^\top$ correspond à une matrice de projection dans l'espace des $k$ premières composantes principales. Il faut cependant traiter le produit matricielle $V_k V_k^\top$ avec attention pour obtenir des résultats précis et rapides. Il est souvent plus judicieux de procéder en deux étapes :
# 1. Calculer les poids $\mathbf{\hat{w}}$.
# 2. Calculer la projection de l'image $\mathbf{\hat{z}}_i^\top = V_k \mathbf{\hat{w}}$.

# %% [markdown]
# ## 3.1 Approximation du visage 1 avec les 10 premiers vecteurs singuliers

# %%
i = 1
k = 10

Vk = V[:,1:k]
zᵢ = Z[i,:];

# %% [markdown]
# ### a) Calculez les coefficients ŵ

# %%
ŵ = Vk'*zᵢ
# Out:
# 10-element Vector{Float64}:
#  -4.868316659849875
#  -9.50806596651548
#  -0.5404498552677186
#  -4.078481857768051
#  -0.97711133011654
#   1.6514921400805302
#  -1.5735094408603016
#   1.3784192719968198
#  -0.7155338779631741
#   4.2214520841515295

# %% [markdown]
# ### b) Calculez l'approximation du visage

# %%
ẑᵢ = Vk * ŵ
# Out:
# 32256-element Vector{Float64}:
#   0.040403333329403254
#   0.04005930498134409
#   0.04151698561619796
#   0.043679602779906374
#   0.047471402624404815
#   0.04901125302299178
#   0.04870555591738305
#   0.04863952176365629
#   0.051050522778549906
#   0.049429113632918006
#   0.050727672009516146
#   0.05217713491189371
#   0.05218359566561932
#   ⋮
#  -0.00684660022172217
#  -0.009737144005298522
#  -0.01235074510869448
#  -0.013818574100775185
#  -0.01646313026057104
#  -0.01949630078768235
#  -0.01848984950763321
#  -0.016837709721630303
#  -0.017887632789746907
#  -0.023371810562864102
#  -0.033173841594621584
#  -0.03811361608258984

# %% [markdown]
# ### c) Affichez le visage original et son approximation
#
# Vous pouvez ajouter le visage moyen pour une meilleure interprétation

# %%
[imshow(ẑᵢ, (m₁, m₂)), imshow(X[1,:], (m₁, m₂))]
# Out:
# 2-element Vector{Matrix{Gray{Float64}}}:
#  [Gray{Float64}(0.3446614813885933) Gray{Float64}(0.35171541175351995) … Gray{Float64}(0.39819565850118177) Gray{Float64}(0.38104674637628105); Gray{Float64}(0.34345251791249126) Gray{Float64}(0.35777387280842365) … Gray{Float64}(0.393816575221751) Gray{Float64}(0.37721973658217955); … ; Gray{Float64}(0.2893163322655662) Gray{Float64}(0.27947544075153025) … Gray{Float64}(0.07714690976650296) Gray{Float64}(0.0861010526921121); Gray{Float64}(0.27767186802060995) Gray{Float64}(0.26864005181389367) … Gray{Float64}(0.06781292039896497) Gray{Float64}(0.06874199792285966)]
#  [Gray{Float64}(0.29957805907172996) Gray{Float64}(0.29957805907172996) … Gray{Float64}(0.24472573839662448) Gray{Float64}(0.2616033755274262); Gray{Float64}(0.3037974683544304) Gray{Float64}(0.29535864978902954) … Gray{Float64}(0.21940928270042193) Gray{Float64}(0.2320675105485232); … ; Gray{Float64}(0.012658227848101266) Gray{Float64}(0.012658227848101266) … Gray{Float64}(0.02109704641350211) Gray{Float64}(0.02109704641350211); Gray{Float64}(0.012658227848101266) Gray{Float64}(0.012658227848101266) … Gray{Float64}(0.012658227848101266) Gray{Float64}(0.008438818565400843)]

# %% [markdown]
# ## 3.2 Approximation du visage 1 avec les 50 premières vecteurs singuliers
#
# Reprenez les étapes précédentes mais cette fois en utilisant les 50 premiers vecteurs singuliers.

# %%
i = 1
k = 50

Vk = V[:,1:k]
zᵢ = Z[i,:]
# Out:
# 32256-element Vector{Float64}:
#   0.06894257703081225
#   0.07191376550620246
#   0.06781712685074034
#   0.06590136054421766
#   0.07182372949179672
#   0.0795618247298919
#   0.06677671068427371
#   0.06938275310124051
#   0.08125750300120047
#   0.07941176470588235
#   0.06563625450180074
#   0.0779511804721888
#   0.08214285714285716
#   ⋮
#  -0.058038215286114345
#  -0.04533813525410156
#  -0.054521808723489384
#  -0.055477190876350516
#  -0.01741696678671467
#  -0.05705282112845132
#  -0.07835134053621441
#  -0.08707482993197278
#  -0.10192076830732287
#  -0.09803421368547416
#  -0.10303621448579428
#  -0.11860244097639051

# %%
ŵ = Vk'*zᵢ
# Out:
# 50-element Vector{Float64}:
#  -4.868316659849875
#  -9.50806596651548
#  -0.5404498552677186
#  -4.078481857768051
#  -0.97711133011654
#   1.6514921400805302
#  -1.5735094408603016
#   1.3784192719968198
#  -0.7155338779631746
#   4.2214520841515295
#  -0.5203653089765424
#   3.9200895761645644
#  -3.1886617311385015
#   ⋮
#  -1.4149098286016375
#  -0.6576830573743231
#   0.5615998985444413
#   0.5973488608208413
#   0.1909903586674136
#  -0.7985178551350693
#   0.3693434504288081
#  -1.248029793313321
#   0.18684740680579687
#  -0.8215515400568204
#   1.136675077847049
#  -0.20567502138984073

# %%
ẑᵢ = Vk * ŵ
# Out:
# 32256-element Vector{Float64}:
#   0.07526563222119358
#   0.06751205177328835
#   0.06580452126147852
#   0.06987391660956245
#   0.07725836029155574
#   0.0772771836631608
#   0.08357986563568812
#   0.08114155813627628
#   0.08039019752542435
#   0.0756417683910258
#   0.07320562416951486
#   0.07057434600433682
#   0.07128461848357613
#   ⋮
#  -0.04289693840726791
#  -0.04437370033658491
#  -0.058266972107264496
#  -0.0605418352931752
#  -0.06340035877182802
#  -0.07018837447319544
#  -0.07709839082543461
#  -0.08314424361611104
#  -0.09272285498699971
#  -0.09054989572399831
#  -0.09241832349209762
#  -0.08505719964701405

# %%
[imshow(ẑᵢ, (m₁, m₂)), imshow(X[1,:], (m₁, m₂))]
# Out:
# 2-element Vector{Matrix{Gray{Float64}}}:
#  [Gray{Float64}(0.5797878035723655) Gray{Float64}(0.5762608769651022) … Gray{Float64}(0.5490648815369877) Gray{Float64}(0.5401393012237411); Gray{Float64}(0.5671702618324509) Gray{Float64}(0.5732370942083831) … Gray{Float64}(0.5350408646129554) Gray{Float64}(0.5462210441825779); … ; Gray{Float64}(0.23863882803099706) Gray{Float64}(0.22398512081446553) … Gray{Float64}(0.27846938166433527) Gray{Float64}(0.30691266871798245); Gray{Float64}(0.23035778099446774) Gray{Float64}(0.21580332886125347) … Gray{Float64}(0.29811490565053284) Gray{Float64}(0.3188915587278379)]
#  [Gray{Float64}(0.29957805907172996) Gray{Float64}(0.29957805907172996) … Gray{Float64}(0.24472573839662448) Gray{Float64}(0.2616033755274262); Gray{Float64}(0.3037974683544304) Gray{Float64}(0.29535864978902954) … Gray{Float64}(0.21940928270042193) Gray{Float64}(0.2320675105485232); … ; Gray{Float64}(0.012658227848101266) Gray{Float64}(0.012658227848101266) … Gray{Float64}(0.02109704641350211) Gray{Float64}(0.02109704641350211); Gray{Float64}(0.012658227848101266) Gray{Float64}(0.012658227848101266) … Gray{Float64}(0.012658227848101266) Gray{Float64}(0.008438818565400843)]

# %% [markdown]
# ## 3.3 Approximation du visage 1 avec les 70 premières vecteurs singuliers
#
# Reprenez les étapes précédentes mais cette fois en utilisant les 70 premiers vecteurs singuliers.

# %%
i = 1
k = 70

Vk = V[:,1:k]
zᵢ = Z[i,:]
# Out:
# 32256-element Vector{Float64}:
#   0.06894257703081225
#   0.07191376550620246
#   0.06781712685074034
#   0.06590136054421766
#   0.07182372949179672
#   0.0795618247298919
#   0.06677671068427371
#   0.06938275310124051
#   0.08125750300120047
#   0.07941176470588235
#   0.06563625450180074
#   0.0779511804721888
#   0.08214285714285716
#   ⋮
#  -0.058038215286114345
#  -0.04533813525410156
#  -0.054521808723489384
#  -0.055477190876350516
#  -0.01741696678671467
#  -0.05705282112845132
#  -0.07835134053621441
#  -0.08707482993197278
#  -0.10192076830732287
#  -0.09803421368547416
#  -0.10303621448579428
#  -0.11860244097639051

# %%
ŵ = Vk'*zᵢ
# Out:
# 70-element Vector{Float64}:
#  -4.868316659849875
#  -9.50806596651548
#  -0.5404498552677186
#  -4.078481857768051
#  -0.97711133011654
#   1.6514921400805302
#  -1.5735094408603016
#   1.3784192719968198
#  -0.7155338779631746
#   4.2214520841515295
#  -0.5203653089765424
#   3.9200895761645644
#  -3.1886617311385015
#   ⋮
#   0.07912166843846899
#  -1.1447875787928075
#   0.027892926298547976
#  -0.06984730010143003
#   0.6666432358300507
#  -0.18100513289615888
#  -0.30201065113523917
#   0.25532440129014045
#  -0.20096529747904213
#   0.8756002689283034
#   0.0547563585297291
#   0.30282347386779784

# %%
ẑᵢ = Vk * ŵ
# Out:
# 32256-element Vector{Float64}:
#   0.07768735695954596
#   0.06971319472727891
#   0.06731194458253363
#   0.07058962753972604
#   0.07849474065781525
#   0.08051562074182654
#   0.0886048151617359
#   0.08513148975505601
#   0.08257581593227069
#   0.07963866211543785
#   0.075329610021422
#   0.07383714160632293
#   0.0752107534123859
#   ⋮
#  -0.031932979847861566
#  -0.03197771921223178
#  -0.04392823621860217
#  -0.04529234048880533
#  -0.04732922714314565
#  -0.05526914017187917
#  -0.061494173611619636
#  -0.06937478808425265
#  -0.07977703572811054
#  -0.07716874234242195
#  -0.07519139387068992
#  -0.06611364798121579

# %%
[imshow(ẑᵢ, (m₁, m₂)), imshow(X[1,:], (m₁, m₂))]
# Out:
# 2-element Vector{Matrix{Gray{Float64}}}:
#  [Gray{Float64}(0.5857318876222671) Gray{Float64}(0.5822839263026874) … Gray{Float64}(0.5518386135567107) Gray{Float64}(0.5475751683477265); Gray{Float64}(0.5728937221469428) Gray{Float64}(0.5769458125251554) … Gray{Float64}(0.5331237288242976) Gray{Float64}(0.5478255647082894); … ; Gray{Float64}(0.22635748488356638) Gray{Float64}(0.20805740410100065) … Gray{Float64}(0.3251998825141319) Gray{Float64}(0.3396016179272838); Gray{Float64}(0.22023682905639877) Gray{Float64}(0.20609932772345457) … Gray{Float64}(0.34663774714450507) Gray{Float64}(0.35421652046844787)]
#  [Gray{Float64}(0.29957805907172996) Gray{Float64}(0.29957805907172996) … Gray{Float64}(0.24472573839662448) Gray{Float64}(0.2616033755274262); Gray{Float64}(0.3037974683544304) Gray{Float64}(0.29535864978902954) … Gray{Float64}(0.21940928270042193) Gray{Float64}(0.2320675105485232); … ; Gray{Float64}(0.012658227848101266) Gray{Float64}(0.012658227848101266) … Gray{Float64}(0.02109704641350211) Gray{Float64}(0.02109704641350211); Gray{Float64}(0.012658227848101266) Gray{Float64}(0.012658227848101266) … Gray{Float64}(0.012658227848101266) Gray{Float64}(0.008438818565400843)]

# %% [markdown]
# ## 3.3 Approximation du visage 29 avec les 50 premières vecteurs singuliers
#
# Reprenez les étapes précédentes mais cette fois avec le visage 29.

# %%
i = 29
k = 50

Vk = V[:,1:k]
zᵢ = Z[i,:]
# Out:
# 32256-element Vector{Float64}:
#   0.09247198879551816
#   0.06407062825130053
#   0.05605242096838739
#   0.046293517406962775
#   0.040451180472188875
#   0.0364245698279311
#   0.023639455782312913
#  -0.0090486194477791
#  -0.012860144057623063
#  -0.05000000000000002
#  -0.07554021608643458
#  -0.0985194077631053
#  -0.090406162464986
#   ⋮
#   0.2164715886354543
#   0.21348539415766313
#   0.20430172068827535
#   0.20334633853541417
#   0.21003401360544222
#   0.19000600240096044
#   0.1843937575030013
#   0.18743497398959585
#   0.1804321728691477
#   0.1725540216086435
#   0.16755202080832338
#   0.15982893157262912

# %%
ŵ = Vk'*zᵢ
# Out:
# 50-element Vector{Float64}:
#   -7.1532605391286435
#  -10.77746784926605
#   -8.771789259444736
#   12.95501826599025
#    3.7105447509303975
#   -7.091074906313483
#    0.5840275683703973
#    4.708991821160244
#    3.509135296432204
#   -0.8442757692533558
#    1.461912766482689
#    2.486783409411015
#    2.689772511517179
#    ⋮
#   -0.9678380077850649
#   -0.30993368486099143
#    1.1193695148127325
#   -0.11451807472802267
#   -0.044235088199914396
#   -0.4986363065994651
#    0.028422556545324884
#    1.3352886648162356
#    1.0365873810569939
#    0.8741067259651887
#   -0.346815036445443
#    0.36951347008307206

# %%
ẑᵢ = Vk * ŵ
# Out:
# 32256-element Vector{Float64}:
#   0.07595468972555933
#   0.08044147799573866
#   0.06792650135902237
#   0.05811776875533925
#   0.04387899285992281
#   0.03636878157063138
#   0.03793884107126214
#   0.010469710885142081
#   0.002615845417470958
#  -0.01824329055945041
#  -0.0328500161034114
#  -0.052057922505628906
#  -0.05296459731708753
#   ⋮
#   0.2457640188699362
#   0.24344095924939832
#   0.22824919197863597
#   0.23251780209308257
#   0.22232967879259727
#   0.23673727296493297
#   0.21650607437694747
#   0.21871038402699863
#   0.2088475756057073
#   0.2061412791312939
#   0.19692667803914252
#   0.19047597559744447

# %%
[imshow(ẑᵢ, (m₁, m₂)), imshow(X[i,:], (m₁, m₂))]
# Out:
# 2-element Vector{Matrix{Gray{Float64}}}:
#  [Gray{Float64}(0.6157164672443378) Gray{Float64}(0.6205595743033999) … Gray{Float64}(0.6712159865444985) Gray{Float64}(0.6968668313773404); Gray{Float64}(0.6214113056231584) Gray{Float64}(0.6188849985491834) … Gray{Float64}(0.676905734742713) Gray{Float64}(0.6923843860469279); … ; Gray{Float64}(0.6994543125632688) Gray{Float64}(0.7098831390444603) … Gray{Float64}(0.7775597254073059) Gray{Float64}(0.7692596879907222); Gray{Float64}(0.672039527362721) Gray{Float64}(0.6779802706879878) … Gray{Float64}(0.7628891281020296) Gray{Float64}(0.7610721592678958)]
#  [Gray{Float64}(0.321285140562249) Gray{Float64}(0.3172690763052209) … Gray{Float64}(0.3734939759036145) Gray{Float64}(0.3694779116465864); Gray{Float64}(0.2931726907630522) Gray{Float64}(0.2971887550200803) … Gray{Float64}(0.36546184738955817) Gray{Float64}(0.3614457831325301); … ; Gray{Float64}(0.2690763052208835) Gray{Float64}(0.2891566265060241) … Gray{Float64}(0.321285140562249) Gray{Float64}(0.30923694779116473); Gray{Float64}(0.2650602409638554) Gray{Float64}(0.2811244979919679) … Gray{Float64}(0.3172690763052209) Gray{Float64}(0.3052208835341366)]

# %% [markdown]
# # 4. Reconnaissance faciale
#
#
# L'idée de la reconnaissance faciale consiste à comparer le vecteur des coefficient $\mathbf{\hat{w}}$ de l'image à reconnaître avec les vecteurs poids des images de l'ensemble d'entraînement. C'est une comparaison assez facile à faire car ce vecteur est de dimension raisonnable comparativement aux images originales. En effet, dans notre cas, si on prend 50 vecteurs singuliers, le vecteur des coefficient est un vecteur colonne de taille 50. On peut donc résumer toutes les images par leur vecteur des coefficients de taille 50.
#
# Pour savoir, si une nouvelle image représente une personne présente dans l'ensemble d'entraînement, on n'a qu'à comparer son vecteur des coefficients avec chacun des vecteurs des coefficients de l'ensemble d'entraînement. Cette comparaison est facile, rapide et efficace car les vecteurs sont de tailles raisonnables. Si la différence entre les vecteurs est très grande, cela suggère que la personne est inconnue de l'ensemble d'entraînement. Si la différence est petite avec un des vecteurs de coefficients, cela suggère qu'il s'agit de la même personne. Le seuil doit être ajusté avec de la validation croisée.
#
# Dans cette section, vous déciderez si une nouvelle image de l'ensemble test représente un personne connue ou inconnue. Vous le ferez en complétant les étapes suivantes :
#
# 1. Calculez les poids de toutes les images de l'ensemble d'entraînement.
# 2. Calculez les poids de l'image de test.
# 3. Calculez la distance entre les vecteurs poids des images d'entraînement et celui de l'image de test.
# 4. Identifiez l'image de l'ensemble d'entraînement la plus proche de l'image de test.
# 5. Décidez si le visage se retrouve dans l'échantillon d'entraînement ou s'il est inconnu.

# %% [markdown]
# ### 4.1 Calculez les poids de toutes les images de l'ensemble d'entraînement
#
# Prenez pour l'instant $k = 50$ composantes.

# %%
k = 50
Vk = V[:,1:k]
# Out:
# 32256×50 Matrix{Float64}:
#   0.00534734  -0.00593475    0.000738375  …   0.00252917   0.000433436
#   0.00540604  -0.00593016    0.000760127      0.00333978   0.000859669
#   0.00544098  -0.00581651    0.000862511      0.00201702   0.00121446
#   0.0054438   -0.00578868    0.000988561      0.00226706   0.00191622
#   0.00542277  -0.00569403    0.00114588       0.00277216   0.00292903
#   0.00546097  -0.00558436    0.00125364   …   0.0029889    0.00323168
#   0.00549627  -0.00555629    0.0013483        0.00508013   0.00210498
#   0.00554805  -0.00550439    0.00151448       0.00351393   0.00261436
#   0.00557532  -0.00557535    0.00162796       0.00475313   0.00450764
#   0.00559203  -0.00540729    0.00162903       0.00404389   0.00506153
#   0.00555506  -0.00540267    0.00170837   …   0.00518042   0.00594849
#   0.00558824  -0.00531072    0.00194505       0.00443184   0.00598709
#   0.00558341  -0.00531839    0.00201843       0.00547262   0.00679297
#   ⋮                                       ⋱
#  -0.00513778  -0.000238549  -0.00489995      -0.00854961  -0.000844416
#  -0.00493542  -0.000204884  -0.00501403   …  -0.00521168  -0.00291491
#  -0.00485675  -0.000128603  -0.00489878      -0.00552181  -0.00319164
#  -0.00478719  -0.000110692  -0.00474301      -0.00526236  -0.00206058
#  -0.00470784   2.39219e-5   -0.00453575      -0.00779755  -0.00129478
#  -0.00463006   2.05732e-5   -0.00459649      -0.00682257  -0.00122842
#  -0.00455832   9.76697e-5   -0.00449218   …  -0.00937458  -0.0011861
#  -0.00461494   6.51091e-5   -0.00447288      -0.0104564    0.000653739
#  -0.00457696   0.000110037  -0.00430993      -0.0132175    0.00195375
#  -0.00455275   0.000174937  -0.00428581      -0.0128151    0.00235183
#  -0.00471819   0.000172073  -0.0045281       -0.0114126    0.00176002
#  -0.00487578   0.000162291  -0.00467062   …  -0.00967881   0.00179897

# %% [markdown]
# ### 4.2 Calculez les poids de l'image de test
#
# Prenons d'abord la première image de l'échantillon de test. Il faut charger l'image, retirer le visage moyen et calculer les poids.

# %%
# Récupération de tous les noms de fichiers de l'échantillon d'entraînement
file = readdir("Test")
testFileName = ["Test/"*file[i] for i=1:length(file)];

# %%
# jᵉ image de l'échantillon de test
j = 1  

# Conversion de l'image de test en intensités de gris et retrait du visage moyen
y = imgrayconvert(testFileName[j]) - X̄
# Out:
# 32256-element Vector{Float64}:
#   0.123844537815126
#   0.11505102040816326
#   0.10703281312525018
#   0.11296018407362943
#   0.13064725890356144
#   0.12662064825930366
#   0.14128651460584235
#   0.13997098839535818
#   0.12439475790316126
#   0.12254901960784309
#   0.11661664665866348
#   0.12501000400160056
#   0.1331232492997199
#   ⋮
#  -0.050195078031212384
#  -0.07278911564625842
#  -0.08197278911564625
#  -0.08292817126850738
#  -0.08016206482593036
#  -0.0805822328931572
#  -0.08227290916366539
#  -0.1027611044417767
#  -0.10976390556222483
#  -0.09411264505802318
#  -0.10303621448579428
#  -0.10683773509403757

# %% [markdown]
# ### 4.3 Calculez la distance euclidienne entre les vecteurs poids des images d'entraînement et celui de l'image de test.

# %% [markdown]
# ### 4.4 Identifiez l'image de l'ensemble d'entraînement la plus proche de l'image de test.

# %% [markdown]
# ### 4.5 Décidez si le visage se retrouve dans l'échantillon d'entraînement ou s'il est inconnu.
#
# Si la distance minimale entre les poids des images d'entraînement et des poids de l'image de test, alors on statuera que le visage est inconnu. Il faut définir cependant définir ce seuil à l'aide de la validation croisée. Tentez d'utiliser le seuil de (3500)^2 et refaites les étapes du numéro 4 avec les autres images de l'ensemble de test.
